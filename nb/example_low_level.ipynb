# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
el_sc = pd.read_csv(
    "data/gene_score.tsv",
    sep="\t",
    index_col=0,
    squeeze=True,
)

# %%
import kwat

# %%
se_el1_ = kwat.gmt.read(["data/c2.all.v7.1.symbols.gmt"])

# %%
import gsea

# %% [markdown]
# ## 1 sample and 1 set

# %%
el1_ = se_el1_["COLLER_MYC_TARGETS_UP"]

# %%
for me in ["ks", "auc", "js"]:

    print("=" * 80)

    print(gsea.score_1_1(el_sc, el1_, me=me, pl=False))
# Out:
# ================================================================================
# 0.8317043368191653
# ================================================================================
# 0.4615393595287836
# ================================================================================
# 0.6800800344724637

# %% [markdown]
# ## 1 sample and n set

# %%
for me in ["ks", "auc", "js"]:

    print("=" * 80)

    print(gsea.score_1_n(el_sc, se_el1_, me=me))
# Out:
# ================================================================================
# {'BIOCARTA_AMAN_PATHWAY': -0.17282000797434227, 'REACTOME_EXTRACELLULAR_MATRIX_ORGANIZATION': 0.2757627955379228, 'GARCIA_TARGETS_OF_FLI1_AND_DAX1_UP': -0.3657475112462827, 'SIMBULAN_PARP1_TARGETS_UP': 0.412200252267393, 'BIOCARTA_CPSF_PATHWAY': 0.6260178437322048, 'WEI_MYCN_TARGETS_WITH_E_BOX': 0.526577088677345, 'PID_RET_PATHWAY': 0.29455911575266436, 'BIOCARTA_S1P_PATHWAY': 0.5821618423886533, 'MARIADASON_RESPONSE_TO_CURCUMIN_SULINDAC_7': 0.4345039124469948, 'REACTOME_GPCR_LIGAND_BINDING': 0.33708385639003113, 'BIOCARTA_VOBESITY_PATHWAY': 0.5772330881364638, 'KEGG_CYTOSOLIC_DNA_SENSING_PATHWAY': 0.33503670785622247, 'HOSHIDA_LIVER_CANCER_SUBCLASS_S3': 0.1743594740545468, 'LIAN_LIPA_TARGETS_3M': 0.29871579602675724, 'SENESE_HDAC3_TARGETS_UP': 0.2603089501722536, 'BIOCARTA_TOB1_PATHWAY': 0.34909958245430533, 'RODRIGUES_THYROID_CARCINOMA_POORLY_DIFFERENTIATED_DN': -0.30928506949507384, 'REACTOME_SUMOYLATION_OF_INTRACELLULAR_RECEPTORS': -0.17385971233642325, 'REACTOME_RNA_POLYMERASE_II_TRANSCRIBES_SNRNA_GENES': 0.4438834280405335, 'BIOCARTA_CTBP1_PATHWAY': 0.2035790131587716, 'KIM_RESPONSE_TO_TSA_AND_DECITABINE_UP': -0.14532870171612344, 'FRIDMAN_SENESCENCE_UP': -0.2802332541575115, 'CREIGHTON_ENDOCRINE_THERAPY_RESISTANCE_2': -0.41674650823972614, 'PAL_PRMT5_TARGETS_DN': 0.3168936007516371, 'REACTOME_BH3_ONLY_PROTEINS_ASSOCIATE_WITH_AND_INACTIVATE_ANTI_APOPTOTIC_BCL_2_MEMBERS': -0.5483949161025647, 'REACTOME_NEURONAL_SYSTEM': 0.1808369415109233, 'REACTOME_LAGGING_STRAND_SYNTHESIS': -0.2212325964295425, 'REACTOME_O_LINKED_GLYCOSYLATION_OF_MUCINS': 0.16013170858174744, 'FUNG_IL2_SIGNALING_2': 0.6668705822676335, 'LU_TUMOR_VASCULATURE_UP': -0.21840623784239463, 'PID_FOXM1_PATHWAY': 0.33925610844424897, 'LEIN_CHOROID_PLEXUS_MARKERS': -0.18093746145209766, 'REACTOME_SIGNALING_BY_ERBB2_IN_CANCER': 0.31570827131551343, 'MOOTHA_PGC': 0.34356192262578783, 'FERRANDO_TAL1_NEIGHBORS': 0.3897814771217682, 'HOLLEMAN_ASPARAGINASE_RESISTANCE_B_ALL_UP': 0.6150035443483631, 'KEGG_GALACTOSE_METABOLISM': 0.42900926665274147, 'TONKS_TARGETS_OF_RUNX1_RUNX1T1_FUSION_SUSTAINED_IN_MONOCYTE_DN': -0.3536082232600045, 'PYEON_HPV_POSITIVE_TUMORS_DN': 0.6244615389643969, 'KOKKINAKIS_METHIONINE_DEPRIVATION_48HR_UP': 0.18522750880793643, 'KEGG_OTHER_GLYCAN_DEGRADATION': 0.4496408881963517, 'WANG_LSD1_TARGETS_DN': -0.37086538643503614, 'KYNG_WERNER_SYNDROM_UP': 0.2790158131535357, 'ZHAN_MULTIPLE_MYELOMA_CD1_AND_CD2_UP': -0.35011751099392574, 'DAZARD_RESPONSE_TO_UV_SCC_UP': 0.18851855017811434, 'RUAN_RESPONSE_TO_TROGLITAZONE_UP': 0.3740109919258749, 'RICKMAN_TUMOR_DIFFERENTIATED_WELL_VS_POORLY_DN': 0.2920199307917611, 'REACTOME_COMPLEX_I_BIOGENESIS': 0.2609077855068752, 'REACTOME_NEF_AND_SIGNAL_TRANSDUCTION': -0.21154390611524831, 'LEI_MYB_TARGETS': 0.28053357521110905, 'CHICAS_RB1_TARGETS_LOW_SERUM': -0.256116825884181, 'REACTOME_LECTIN_PATHWAY_OF_COMPLEMENT_ACTIVATION': 0.2925829021269372, 'SHEN_SMARCA2_TARGETS_DN': 0.39413792923250174, 'REACTOME_SIGNALING_BY_RETINOIC_ACID': 0.33364403446890206, 'XU_CREBBP_TARGETS_UP': 0.6289056714977257, 'MEISSNER_ES_ICP_WITH_H3K4ME3_AND_H3K27ME3': 0.42260426782945765, 'LU_TUMOR_ENDOTHELIAL_MARKERS_DN': 0.3535224750859184, 'REACTOME_NECTIN_NECL_TRANS_HETERODIMERIZATION': 0.4897826850205611, 'GAUSSMANN_MLL_AF4_FUSION_TARGETS_E_DN': -0.18465524945599407, 'PID_NFAT_3PATHWAY': -0.2571046617121865, 'VILIMAS_NOTCH1_TARGETS_UP': 0.2931408552720345, 'REACTOME_TFAP2A_ACTS_AS_A_TRANSCRIPTIONAL_REPRESSOR_DURING_RETINOIC_ACID_INDUCED_CELL_DIFFERENTIATION': 0.6944432956196981, 'REACTOME_SYNTHESIS_OF_PIPS_AT_THE_EARLY_ENDOSOME_MEMBRANE': -0.2352186559698152, 'NADERI_BREAST_CANCER_PROGNOSIS_DN': -0.6270547352374042, 'LANDIS_ERBB2_BREAST_TUMORS_324_UP': -0.2724167989891875, 'KEGG_PRIMARY_BILE_ACID_BIOSYNTHESIS': -0.2368739538145597, 'REACTOME_REGULATION_OF_TP53_ACTIVITY_THROUGH_PHOSPHORYLATION': 0.2349888844611991, 'REACTOME_BETA_OXIDATION_OF_DECANOYL_COA_TO_OCTANOYL_COA_COA': 0.5587271508076227, 'PID_TRAIL_PATHWAY': -0.22139179326436617, ' ...
# ================================================================================
# {'BIOCARTA_AMAN_PATHWAY': -0.01989676017768015, 'REACTOME_EXTRACELLULAR_MATRIX_ORGANIZATION': 0.12685009163534, 'GARCIA_TARGETS_OF_FLI1_AND_DAX1_UP': -0.15696232607602914, 'SIMBULAN_PARP1_TARGETS_UP': 0.17761220718146725, 'BIOCARTA_CPSF_PATHWAY': 0.27090515899316986, 'WEI_MYCN_TARGETS_WITH_E_BOX': 0.29387126064861624, 'PID_RET_PATHWAY': 0.07795719571766065, 'BIOCARTA_S1P_PATHWAY': 0.3112773109392594, 'MARIADASON_RESPONSE_TO_CURCUMIN_SULINDAC_7': 0.20565368332896466, 'REACTOME_GPCR_LIGAND_BINDING': 0.17176149773272767, 'BIOCARTA_VOBESITY_PATHWAY': 0.2256496256238647, 'KEGG_CYTOSOLIC_DNA_SENSING_PATHWAY': 0.17640480229042452, 'HOSHIDA_LIVER_CANCER_SUBCLASS_S3': 0.04491021163449959, 'LIAN_LIPA_TARGETS_3M': 0.11232245671641217, 'SENESE_HDAC3_TARGETS_UP': 0.1032091124140676, 'BIOCARTA_TOB1_PATHWAY': 0.11499622210180424, 'RODRIGUES_THYROID_CARCINOMA_POORLY_DIFFERENTIATED_DN': -0.11952200351280828, 'REACTOME_SUMOYLATION_OF_INTRACELLULAR_RECEPTORS': -0.024072573021192503, 'REACTOME_RNA_POLYMERASE_II_TRANSCRIBES_SNRNA_GENES': 0.19729755022431963, 'BIOCARTA_CTBP1_PATHWAY': 0.022024356546551518, 'KIM_RESPONSE_TO_TSA_AND_DECITABINE_UP': 0.007985686284302638, 'FRIDMAN_SENESCENCE_UP': -0.06343046737488396, 'CREIGHTON_ENDOCRINE_THERAPY_RESISTANCE_2': -0.2122423574747607, 'PAL_PRMT5_TARGETS_DN': 0.07801621691761933, 'REACTOME_BH3_ONLY_PROTEINS_ASSOCIATE_WITH_AND_INACTIVATE_ANTI_APOPTOTIC_BCL_2_MEMBERS': -0.2247310465503245, 'REACTOME_NEURONAL_SYSTEM': 0.03135125178515473, 'REACTOME_LAGGING_STRAND_SYNTHESIS': 0.016299498891219316, 'REACTOME_O_LINKED_GLYCOSYLATION_OF_MUCINS': 0.02163846144068394, 'FUNG_IL2_SIGNALING_2': 0.3892191099762363, 'LU_TUMOR_VASCULATURE_UP': -0.03628040900140059, 'PID_FOXM1_PATHWAY': 0.1212208821613397, 'LEIN_CHOROID_PLEXUS_MARKERS': -0.024114317444485462, 'REACTOME_SIGNALING_BY_ERBB2_IN_CANCER': 0.15677305758468904, 'MOOTHA_PGC': 0.15603846763138282, 'FERRANDO_TAL1_NEIGHBORS': 0.18452066526871536, 'HOLLEMAN_ASPARAGINASE_RESISTANCE_B_ALL_UP': 0.38300913974212075, 'KEGG_GALACTOSE_METABOLISM': 0.2263022598724671, 'TONKS_TARGETS_OF_RUNX1_RUNX1T1_FUSION_SUSTAINED_IN_MONOCYTE_DN': -0.15316485351424136, 'PYEON_HPV_POSITIVE_TUMORS_DN': 0.32552574718899996, 'KOKKINAKIS_METHIONINE_DEPRIVATION_48HR_UP': 2.1730118296140347e-05, 'KEGG_OTHER_GLYCAN_DEGRADATION': 0.1672261647999985, 'WANG_LSD1_TARGETS_DN': -0.10680233758836064, 'KYNG_WERNER_SYNDROM_UP': 0.059385340645403, 'ZHAN_MULTIPLE_MYELOMA_CD1_AND_CD2_UP': -0.15482463963937426, 'DAZARD_RESPONSE_TO_UV_SCC_UP': 0.052647601385198285, 'RUAN_RESPONSE_TO_TROGLITAZONE_UP': 0.14011637343305058, 'RICKMAN_TUMOR_DIFFERENTIATED_WELL_VS_POORLY_DN': 0.13891851376582764, 'REACTOME_COMPLEX_I_BIOGENESIS': 0.10430326740286835, 'REACTOME_NEF_AND_SIGNAL_TRANSDUCTION': -0.018330282823104074, 'LEI_MYB_TARGETS': 0.12462890027725587, 'CHICAS_RB1_TARGETS_LOW_SERUM': -0.02332574055128323, 'REACTOME_LECTIN_PATHWAY_OF_COMPLEMENT_ACTIVATION': 0.09316373059957565, 'SHEN_SMARCA2_TARGETS_DN': 0.20546707273571438, 'REACTOME_SIGNALING_BY_RETINOIC_ACID': 0.15673503392150798, 'XU_CREBBP_TARGETS_UP': 0.31802858780191834, 'MEISSNER_ES_ICP_WITH_H3K4ME3_AND_H3K27ME3': 0.17733684057051988, 'LU_TUMOR_ENDOTHELIAL_MARKERS_DN': 0.15320937734563, 'REACTOME_NECTIN_NECL_TRANS_HETERODIMERIZATION': 0.09537747886378509, 'GAUSSMANN_MLL_AF4_FUSION_TARGETS_E_DN': -0.046511837673495184, 'PID_NFAT_3PATHWAY': -0.09353041622899698, 'VILIMAS_NOTCH1_TARGETS_UP': 0.10060172222538313, 'REACTOME_TFAP2A_ACTS_AS_A_TRANSCRIPTIONAL_REPRESSOR_DURING_RETINOIC_ACID_INDUCED_CELL_DIFFERENTIATION': 0.2690497657221276, 'REACTOME_SYNTHESIS_OF_PIPS_AT_THE_EARLY_ENDOSOME_MEMBRANE': -0.03297259416525068, 'NADERI_BREAST_CANCER_PROGNOSIS_DN': -0.3581887812316751, 'LANDIS_ERBB2_BREAST_TUMORS_324_UP': -0.084531917912361, 'KEGG_PRIMARY_BILE_ACID_BIOSYNTHESIS': 0.0011200692255615037, 'REACTOME_REGULATION_OF_TP53_ACTIVITY_THROUGH_PHOSPHORYLATION': 0.06686745598804081, 'REACTOME_BETA_OXIDATION_OF_DECANOYL_COA_TO_OCTANOYL_COA_COA': 0.24602674721291407, 'PID_TRAIL_ ...
# ================================================================================
# {'BIOCARTA_AMAN_PATHWAY': -0.10899788581043979, 'REACTOME_EXTRACELLULAR_MATRIX_ORGANIZATION': 0.16382936584147906, 'GARCIA_TARGETS_OF_FLI1_AND_DAX1_UP': -0.3740564658328005, 'SIMBULAN_PARP1_TARGETS_UP': 0.2625517317643302, 'BIOCARTA_CPSF_PATHWAY': 0.4319430133717384, 'WEI_MYCN_TARGETS_WITH_E_BOX': 0.5016233595245608, 'PID_RET_PATHWAY': 0.07667540453957988, 'BIOCARTA_S1P_PATHWAY': 0.4217058636343636, 'MARIADASON_RESPONSE_TO_CURCUMIN_SULINDAC_7': 0.3138110720340224, 'REACTOME_GPCR_LIGAND_BINDING': 0.2503486580099675, 'BIOCARTA_VOBESITY_PATHWAY': 0.2728140320157133, 'KEGG_CYTOSOLIC_DNA_SENSING_PATHWAY': 0.26324992642654993, 'HOSHIDA_LIVER_CANCER_SUBCLASS_S3': 0.010994708334560843, 'LIAN_LIPA_TARGETS_3M': 0.13805416760366013, 'SENESE_HDAC3_TARGETS_UP': 0.12747235518033037, 'BIOCARTA_TOB1_PATHWAY': 0.14686183421883145, 'RODRIGUES_THYROID_CARCINOMA_POORLY_DIFFERENTIATED_DN': -0.3200165784713407, 'REACTOME_SUMOYLATION_OF_INTRACELLULAR_RECEPTORS': -0.11412787404193503, 'REACTOME_RNA_POLYMERASE_II_TRANSCRIBES_SNRNA_GENES': 0.29963354341625004, 'BIOCARTA_CTBP1_PATHWAY': -0.038160987065808706, 'KIM_RESPONSE_TO_TSA_AND_DECITABINE_UP': -0.0611464873337658, 'FRIDMAN_SENESCENCE_UP': -0.2007153448069303, 'CREIGHTON_ENDOCRINE_THERAPY_RESISTANCE_2': -0.499253901755421, 'PAL_PRMT5_TARGETS_DN': 0.07275381783813292, 'REACTOME_BH3_ONLY_PROTEINS_ASSOCIATE_WITH_AND_INACTIVATE_ANTI_APOPTOTIC_BCL_2_MEMBERS': -0.5217151863092602, 'REACTOME_NEURONAL_SYSTEM': -0.015235631811120075, 'REACTOME_LAGGING_STRAND_SYNTHESIS': -0.04617589379939514, 'REACTOME_O_LINKED_GLYCOSYLATION_OF_MUCINS': -0.033877565022475575, 'FUNG_IL2_SIGNALING_2': 0.6225933923819336, 'LU_TUMOR_VASCULATURE_UP': -0.14715718139234188, 'PID_FOXM1_PATHWAY': 0.16611680565365983, 'LEIN_CHOROID_PLEXUS_MARKERS': -0.12533957661577594, 'REACTOME_SIGNALING_BY_ERBB2_IN_CANCER': 0.21598428144384846, 'MOOTHA_PGC': 0.2364732624064835, 'FERRANDO_TAL1_NEIGHBORS': 0.24527963367258696, 'HOLLEMAN_ASPARAGINASE_RESISTANCE_B_ALL_UP': 0.5926142993791658, 'KEGG_GALACTOSE_METABOLISM': 0.3597836733156731, 'TONKS_TARGETS_OF_RUNX1_RUNX1T1_FUSION_SUSTAINED_IN_MONOCYTE_DN': -0.3323793747339427, 'PYEON_HPV_POSITIVE_TUMORS_DN': 0.4749002921597038, 'KOKKINAKIS_METHIONINE_DEPRIVATION_48HR_UP': -0.07654409203872012, 'KEGG_OTHER_GLYCAN_DEGRADATION': 0.24203370636286325, 'WANG_LSD1_TARGETS_DN': -0.29226638028551694, 'KYNG_WERNER_SYNDROM_UP': 0.05471112587612406, 'ZHAN_MULTIPLE_MYELOMA_CD1_AND_CD2_UP': -0.3864423606075911, 'DAZARD_RESPONSE_TO_UV_SCC_UP': 0.027158917343664393, 'RUAN_RESPONSE_TO_TROGLITAZONE_UP': 0.19238643884944776, 'RICKMAN_TUMOR_DIFFERENTIATED_WELL_VS_POORLY_DN': 0.19318331476892692, 'REACTOME_COMPLEX_I_BIOGENESIS': 0.1264993826498685, 'REACTOME_NEF_AND_SIGNAL_TRANSDUCTION': -0.11419631797705901, 'LEI_MYB_TARGETS': 0.1684594938296378, 'CHICAS_RB1_TARGETS_LOW_SERUM': -0.12679172860853438, 'REACTOME_LECTIN_PATHWAY_OF_COMPLEMENT_ACTIVATION': 0.10132714196264829, 'SHEN_SMARCA2_TARGETS_DN': 0.313644362824184, 'REACTOME_SIGNALING_BY_RETINOIC_ACID': 0.2063369847243169, 'XU_CREBBP_TARGETS_UP': 0.5469260980904167, 'MEISSNER_ES_ICP_WITH_H3K4ME3_AND_H3K27ME3': 0.2562240046627071, 'LU_TUMOR_ENDOTHELIAL_MARKERS_DN': 0.18961334044829742, 'REACTOME_NECTIN_NECL_TRANS_HETERODIMERIZATION': 0.11151923381526559, 'GAUSSMANN_MLL_AF4_FUSION_TARGETS_E_DN': -0.1494064097156477, 'PID_NFAT_3PATHWAY': -0.2589310890273275, 'VILIMAS_NOTCH1_TARGETS_UP': 0.1223260412265882, 'REACTOME_TFAP2A_ACTS_AS_A_TRANSCRIPTIONAL_REPRESSOR_DURING_RETINOIC_ACID_INDUCED_CELL_DIFFERENTIATION': 0.4767808107707365, 'REACTOME_SYNTHESIS_OF_PIPS_AT_THE_EARLY_ENDOSOME_MEMBRANE': -0.13040331167499816, 'NADERI_BREAST_CANCER_PROGNOSIS_DN': -0.6724233021348276, 'LANDIS_ERBB2_BREAST_TUMORS_324_UP': -0.2528785664951881, 'KEGG_PRIMARY_BILE_ACID_BIOSYNTHESIS': -0.07354682834829487, 'REACTOME_REGULATION_OF_TP53_ACTIVITY_THROUGH_PHOSPHORYLATION': 0.055904297018100846, 'REACTOME_BETA_OXIDATION_OF_DECANOYL_COA_TO_OCTANOYL_COA_COA': 0.40118378624881784, 'PID_TRAIL_PATHWAY': -0. ...

# %% [markdown]
# ## n sample and n set

# %%
sc_el_sa = pd.concat([el_sc, el_sc * 10, el_sc / 10], axis=1)

sc_el_sa.columns = ["Sample {}".format(ie) for ie in range(sc_el_sa.shape[1])]

# %%
for me in ["ks", "auc", "js"]:

    print("=" * 80)

    print(gsea.score_n_n(sc_el_sa, se_el1_, me=me))
# Out:
# ================================================================================
#                                             Sample 2  Sample 1  Sample 0
# Set
# GRABARCZYK_BCL11B_TARGETS_UP               -0.274847 -0.274847 -0.274847
# REACTOME_EXTRACELLULAR_MATRIX_ORGANIZATION  0.275763  0.275763  0.275763
# GARCIA_TARGETS_OF_FLI1_AND_DAX1_UP         -0.365748 -0.365748 -0.365748
# SIMBULAN_PARP1_TARGETS_UP                   0.412200  0.412200  0.412200
# BIOCARTA_CPSF_PATHWAY                       0.626018  0.626018  0.626018
# ...                                              ...       ...       ...
# STEGER_ADIPOGENESIS_DN                      0.262480  0.262480  0.262480
# NIKOLSKY_BREAST_CANCER_20Q12_Q13_AMPLICON   0.312327  0.312327  0.312327
# VERRECCHIA_RESPONSE_TO_TGFB1_C6             0.504835  0.504835  0.504835
# SCHAEFFER_PROSTATE_DEVELOPMENT_6HR_UP      -0.230513 -0.230513 -0.230513
# BIOCARTA_AMAN_PATHWAY                      -0.172820 -0.172820 -0.172820
#
# [5529 rows x 3 columns]
# ================================================================================
#                                             Sample 2  Sample 1  Sample 0
# Set
# GRABARCZYK_BCL11B_TARGETS_UP               -0.092702 -0.092702 -0.092702
# REACTOME_EXTRACELLULAR_MATRIX_ORGANIZATION  0.126850  0.126850  0.126850
# GARCIA_TARGETS_OF_FLI1_AND_DAX1_UP         -0.156962 -0.156962 -0.156962
# SIMBULAN_PARP1_TARGETS_UP                   0.177612  0.177612  0.177612
# BIOCARTA_CPSF_PATHWAY                       0.270905  0.270905  0.270905
# ...                                              ...       ...       ...
# STEGER_ADIPOGENESIS_DN                      0.080310  0.080310  0.080310
# NIKOLSKY_BREAST_CANCER_20Q12_Q13_AMPLICON   0.129178  0.129178  0.129178
# VERRECCHIA_RESPONSE_TO_TGFB1_C6             0.097242  0.097242  0.097242
# SCHAEFFER_PROSTATE_DEVELOPMENT_6HR_UP      -0.036804 -0.036804 -0.036804
# BIOCARTA_AMAN_PATHWAY                      -0.019897 -0.019897 -0.019897
#
# [5529 rows x 3 columns]
# ================================================================================
#                                             Sample 2  Sample 1  Sample 0
# Set
# GRABARCZYK_BCL11B_TARGETS_UP               -0.260201 -0.260201 -0.260201
# REACTOME_EXTRACELLULAR_MATRIX_ORGANIZATION  0.163829  0.163829  0.163829
# GARCIA_TARGETS_OF_FLI1_AND_DAX1_UP         -0.374056 -0.374056 -0.374056
# SIMBULAN_PARP1_TARGETS_UP                   0.262552  0.262552  0.262552
# BIOCARTA_CPSF_PATHWAY                       0.431943  0.431943  0.431943
# ...                                              ...       ...       ...
# STEGER_ADIPOGENESIS_DN                      0.082163  0.082163  0.082163
# NIKOLSKY_BREAST_CANCER_20Q12_Q13_AMPLICON   0.176508  0.176508  0.176508
# VERRECCHIA_RESPONSE_TO_TGFB1_C6             0.117504  0.117504  0.117504
# SCHAEFFER_PROSTATE_DEVELOPMENT_6HR_UP      -0.154425 -0.154425 -0.154425
# BIOCARTA_AMAN_PATHWAY                      -0.108998 -0.108998 -0.108998
#
# [5529 rows x 3 columns]
