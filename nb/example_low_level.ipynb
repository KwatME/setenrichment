# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
el_sc = pd.read_csv(
    "data/gene_score.tsv",
    sep="\t",
    index_col=0,
    squeeze=True,
)

# %%
import kwat

# %%
se_el1_ = kwat.gmt.read(["data/c2.all.v7.1.symbols.gmt"])

# %% [markdown]
# ## 1 sample and 1 set

# %%
from gsea import _score_1_1

# %%
el1_ = se_el1_["COLLER_MYC_TARGETS_UP"]

# %%
for me in ["ks", "auc", "js"]:
    
    print(_score_1_1(el_sc, el1_, me=me, pl=False))

# %% [markdown]
# ## 1 sample and n set

# %%
from gsea import _score_1_n

# %%
for me in ["ks", "auc", "js"]:
    
    _score_1_n(el_sc, se_el1_, me=me)

# %% [markdown]
# ## n sample and n set

# %%
from gsea import _score_n_n

# %%
sc_el_sa = pd.concat([el_sc, el_sc * 10, el_sc / 10], axis=1)

sc_el_sa.columns = ["Sample {}".format(ie) for ie in range(sc_el_sa.shape[1])]

# %%
for me in ["ks", "auc", "js"]:
    
    print(_score_n_n(sc_el_sa, se_el1_, me=me))
