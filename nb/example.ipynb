# %%
import pandas as pd

# %%
el_sc = pd.read_csv(
    "/Users/kwat/code/tool/kwat.py/nb/data/gene_score.tsv",
    sep="\t",
    index_col=0,
    squeeze=True,
)

# %%
import kraft

# %%
se_el1_ = kraft.gmt.read(["/Users/kwat/code/tool/kwat.py/nb/data/b.gmt"])

# %% [markdown]
# ## 1 sample : 1 set

# %%
from gsea import score_1_sample_1_set

# %%
el1_ = se_el1_["COLLER_MYC_TARGETS_UP"]

score_1_sample_1_set(el_sc, el1_, pl=False)

# %% [markdown]
# ## 1 sample : n set

# %%
from gsea import score_1_sample_n_set

# %%
score_1_sample_n_set(el_sc, se_el1_)

# %% [markdown]
# ## n sample : n set

# %%
from gsea import score_n_sample_n_set

# %%
sc_el_sa = pd.concat([el_sc, el_sc * 10, el_sc / 10], axis=1)

sc_el_sa.columns = ["Sample {}".format(ie) for ie in range(sc_el_sa.shape[1])]

score_n_sample_n_set(sc_el_sa, se_el1_)
