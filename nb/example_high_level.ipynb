# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
sc_ge_sa = pd.read_csv("data/nmf_k9_w.tsv", sep="\t", index_col=0)

sc_ge_sa
# Out:
#            BRAF-MAPK       EMT    ERBB3-PI3K     HNF1-PAX8  KRAS-AP1  \
# Gene
# AADACL2     0.033448  0.036232  1.729506e-02  5.578041e-21  0.113152
# ABAT        0.224101  0.465587  5.541977e-01  1.218166e-01  0.392697
# ABCA12      0.239067  0.084578  8.142060e-01  3.961628e-01  0.485017
# ABCC4       0.559718  0.676064  1.634132e-01  9.032927e-01  0.451032
# ABLIM1      0.320822  0.519155  8.784333e-01  1.029766e+00  0.895138
# ...              ...       ...           ...           ...       ...
# ZNF512      0.653848  0.735576  4.995299e-01  8.225369e-01  0.600455
# ZNF589      0.562561  0.448505  4.916620e-01  2.614929e-01  0.335688
# ZNF736P9Y   0.021685  0.097331  5.161317e-12  1.124206e-01  0.132964
# ZNF883      0.366848  0.634495  3.809757e-01  1.892805e-01  0.088607
# ZXDB        0.435945  0.581530  5.243845e-01  5.068746e-01  0.413980
#
#                 MYC       MYC-E2F  RAS-WNT-PI3K  TNF-NFKB-YAP
# Gene
# AADACL2    0.076390  4.999544e-02  1.262271e-01  1.629341e-02
# ABAT       0.594219  4.956265e-01  2.811286e-01  8.181135e-17
# ABCA12     0.242416  1.683689e-13  6.732805e-19  2.653811e-09
# ABCC4      0.541918  9.024326e-01  6.963735e-01  6.811373e-01
# ABLIM1     0.711699  7.368907e-01  1.070892e+00  3.797250e-01
# ...             ...           ...           ...           ...
# ZNF512     1.018122  7.446630e-01  6.432619e-01  9.228636e-01
# ZNF589     0.621088  9.754915e-01  6.058554e-01  4.533460e-01
# ZNF736P9Y  0.012849  3.122274e-13  1.352716e-01  3.997852e-02
# ZNF883     0.511772  5.423905e-01  4.890213e-02  3.344063e-01
# ZXDB       0.604760  7.149451e-01  5.188556e-01  4.742413e-01
#
# [1000 rows x 9 columns]

# %%
gm = pd.read_csv(
    "data/h.all.v7.1.symbols.gmt", sep="\t", header=None, index_col=0
).drop(1, axis=1)

gm
# Out:
#                                                 2         3         4    \
# 0
# HALLMARK_TNFA_SIGNALING_VIA_NFKB               JUNB     CXCL2      ATF3
# HALLMARK_HYPOXIA                               PGK1      PDK1      GBE1
# HALLMARK_CHOLESTEROL_HOMEOSTASIS               FDPS   CYP51A1      IDI1
# HALLMARK_MITOTIC_SPINDLE                    ARHGEF2    CLASP1     KIF11
# HALLMARK_WNT_BETA_CATENIN_SIGNALING             MYC    CTNNB1      JAG2
# HALLMARK_TGF_BETA_SIGNALING                  TGFBR1     SMAD7     TGFB1
# HALLMARK_IL6_JAK_STAT3_SIGNALING               IL4R     IL6ST     STAT1
# HALLMARK_DNA_REPAIR                          POLR2H    POLR2A    POLR2G
# HALLMARK_G2M_CHECKPOINT                       AURKA     CCNA2     TOP2A
# HALLMARK_APOPTOSIS                            CASP3     CASP9      DFFA
# HALLMARK_NOTCH_SIGNALING                       JAG1    NOTCH3    NOTCH2
# HALLMARK_ADIPOGENESIS                         FABP4    ADIPOQ     PPARG
# HALLMARK_ESTROGEN_RESPONSE_EARLY              GREB1      CA12  SLC9A3R1
# HALLMARK_ESTROGEN_RESPONSE_LATE                TFF1  SLC9A3R1   TPD52L1
# HALLMARK_ANDROGEN_RESPONSE                     KLK3      KLK2     ACSL3
# HALLMARK_MYOGENESIS                           ACTA1     TNNI2      MYL1
# HALLMARK_PROTEIN_SECRETION                    ARCN1    TMED10     COPB2
# HALLMARK_INTERFERON_ALPHA_RESPONSE              MX1     ISG15      OAS1
# HALLMARK_INTERFERON_GAMMA_RESPONSE            STAT1     ISG15     IFIT1
# HALLMARK_APICAL_JUNCTION                      ACTN1     CLDN7     ACTN3
# HALLMARK_APICAL_SURFACE                     B4GALT1      RHCG       MAL
# HALLMARK_HEDGEHOG_SIGNALING                     SHH     PTCH1     NRCAM
# HALLMARK_COMPLEMENT                              C2       C1S       CFB
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE             ATF4   HERPUD1      PARN
# HALLMARK_PI3K_AKT_MTOR_SIGNALING              MAPK8    PIK3R3      GRB2
# HALLMARK_MTORC1_SIGNALING                     FADS1     DDIT4      CALR
# HALLMARK_E2F_TARGETS                          AURKA     BRCA2    CCP110
# HALLMARK_MYC_TARGETS_V1                        PCNA     PSMD8     PSMD7
# HALLMARK_MYC_TARGETS_V2                     SLC19A1     MRTO4    TMEM97
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION   COL3A1    COL5A2    COL5A1
# HALLMARK_INFLAMMATORY_RESPONSE               CXCL10      CCL2      CCL5
# HALLMARK_XENOBIOTIC_METABOLISM               CYP1A1       FAH      DCXR
# HALLMARK_FATTY_ACID_METABOLISM                ACAA1     ACAA2     ACADL
# HALLMARK_OXIDATIVE_PHOSPHORYLATION           NDUFS3     UQCRB    NDUFS2
# HALLMARK_GLYCOLYSIS                            PGK1     ALDOA      ENO1
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY        GSR     PRDX2    TXNRD1
# HALLMARK_P53_PATHWAY                         CDKN1A      BTG2      MDM2
# HALLMARK_UV_RESPONSE_UP                        NXF1    SLC6A8      BAK1
# HALLMARK_UV_RESPONSE_DN                        TJP1      NFIB    TGFBR3
# HALLMARK_ANGIOGENESIS                          VCAN     POSTN     FSTL1
# HALLMARK_HEME_METABOLISM                      ALAS2      PPOX      FECH
# HALLMARK_COAGULATION                             F2      PROC       C1S
# HALLMARK_IL2_STAT5_SIGNALING                  SOCS2      CISH      PIM1
# HALLMARK_BILE_ACID_METABOLISM                  SCP2     ABCD3   SLC27A2
# HALLMARK_PEROXISOME                           ABCD3     ACOT8     ACOX1
# HALLMARK_ALLOGRAFT_REJECTION                  PTPRC     IL12B     TGFB1
# HALLMARK_SPERMATOGENESIS                      PDHA2     TSSK2      TNP1
# HALLMARK_KRAS_SIGNALING_UP                  ANGPTL4     ITGA2     SPRY2
# HALLMARK_KRAS_SIGNALING_DN                    CDH16    SPTBN2     FGFR3
# HALLMARK_PANCREAS_BETA_CELLS                   PAX6   NEUROD1      ISL1
#
#                                                5         6         7    \
# 0
# HALLMARK_TNFA_SIGNALING_VIA_NFKB            NFKBIA   TNFAIP3     PTGS2
# HALLMARK_HYPOXIA                              PFKL     ALDOA      ENO2
# HALLMARK_CHOLESTEROL_HOMEOSTASIS             FDFT1     DHCR7      SQLE
# HALLMARK_MITOTIC_SPINDLE                     KIF23      ALS2      ARF6
# HALLMARK_WNT_BETA_CATENIN_SIGNALING         NOTCH1      DLL1     AXIN2
# HALLMARK_TGF_BETA_SIGNALING                 SMURF2    SMURF1     BMPR2
# HALLMARK_IL6_JAK_STAT3_SIGNALING             IL1R1    CSF2RB     SOCS3
# HALLMARK_DNA_REPAIR                         POLR2E    POLR2J    POLR2F
# HALLMARK_G2M_CHECKPOINT                      CCNB2     CENPA     BIRC5
# HALLMARK_APOPTOSIS                           CASP7     CFLAR     BIRC3
# HALLMARK_NOTCH_SIGNALING                     APH1A      HES1     CCND1
# HALLMARK_ADIPOGENESIS                         LIPE     DGAT1       LPL
# HALLMARK_ESTROGEN_RESPONSE_EARLY               MYB     ANXA9    IGFBP4
# HALLMARK_ESTROGEN_RESPONSE_LATE             PRSS23      CA12     PDZK1
# HALLMARK_ANDROGEN_RESPONSE                   PIAS1    CAMKK2    NKX3-1
# HALLMARK_MYOGENESIS                          TNNC1     TNNC2      MYH3
# HALLMARK_PROTEIN_SECRETION                   RAB14     ATP7A     COPB1
# HALLMARK_INTERFERON_ALPHA_RESPONSE           IFIT3     IFI44     IFI35
# HALLMARK_INTERFERON_GAMMA_RESPONSE             MX1     IFIT3     IFI35
# HALLMARK_APICAL_JUNCTION                    CLDN19      DLG1      TJP1
# HALLMARK_APICAL_SURFACE                      LYPD3     PKHD1  ATP6V0A4
# HALLMARK_HEDGEHOG_SIGNALING                   NRP1      SCG2      AMOT
# HALLMARK_COMPLEMENT                            C1R  SERPINE1     MMP14
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE          EXOSC4   HSP90B1      XBP1
# HALLMARK_PI3K_AKT_MTOR_SIGNALING            NFKBIB    MAP2K6     MAPK9
# HALLMARK_MTORC1_SIGNALING                      HK2      PGK1    SLC7A5
# HALLMARK_E2F_TARGETS                         CENPE      CKS2   DCLRE1B
# HALLMARK_MYC_TARGETS_V1                        SET    SNRPA1       RAN
# HALLMARK_MYC_TARGETS_V2                       RRP9      PES1     TFB2M
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION    FBN1    COL1A1       FN1
# HALLMARK_INFLAMMATORY_RESPONSE                FPR1     CCL20      IL1A
# HALLMARK_XENOBIOTIC_METABOLISM              CYP1A2     GSTA3    CYP2J2
# HALLMARK_FATTY_ACID_METABOLISM               ACADM     ACOT8     ACOX1
# HALLMARK_OXIDATIVE_PHOSPHORYLATION            SDHA    UQCRC1    NDUFA9
# HALLMARK_GLYCOLYSIS                           TPI1      PFKP     ERO1A
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY      SOD1      GCLC       CAT
# HALLMARK_P53_PATHWAY                         CCNG1       FAS      TOB1
# HALLMARK_UV_RESPONSE_UP                      CDC5L     HSPA2    POLR2H
# HALLMARK_UV_RESPONSE_DN                       TFPI     MMP16     ABCC1
# HALLMARK_ANGIOGENESIS                       LRPAP1      STC1       LPL
# HALLMARK_HEME_METABOLISM                      HMBS      GYPB      ALAD
# HALLMARK_COAGULATION                         MMP14       F10       PLG
# HALLMARK_IL2_STAT5_SIGNALING                 IL2RA   TNFRSF4     SOCS1
# HALLMARK_BILE_ACID_METABOLISM               HSD3B7   HSD17B4    AKR1D1
# HALLMARK_PEROXISOME                          ACSL1      ECH1      ECI2
# HALLMARK_ALLOGRAFT_REJECTION                 IL12A      CD3E      CD3D
# HALLMARK_SPERMATOGENESIS                      ZPBP     DPEP3     ADAM2
# HALLMARK_KRAS_SIGNALING_UP                   HBEGF      RBP4   HSD11B1
# HALLMARK_KRAS_SIGNALING_DN                    NOS1     PDE6B     SIDT1
# HALLMARK_PANCREAS_BETA_CELLS                NKX2-2     PCSK1    NKX6-1
#
#                                                  8         9         10   \
# 0
# HALLMARK_TNFA_SIGNALING_VIA_NFKB               CXCL1      IER3      CD83
# HALLMARK_HYPOXIA                                PGM1     NDRG1       HK2
# HALLMARK_CHOLESTEROL_HOMEOSTASIS              HMGCS1     NSDHL       LSS
# HALLMARK_MITOTIC_SPINDLE                       MYO9B      MYH9   TUBGCP3
# HALLMARK_WNT_BETA_CATENIN_SIGNALING            PSEN2      FZD1    NOTCH4
# HALLMARK_TGF_BETA_SIGNALING                     SKIL       SKI     ACVR1
# HALLMARK_IL6_JAK_STAT3_SIGNALING               STAT3      OSMR     IL2RG
# HALLMARK_DNA_REPAIR                           POLR2C    POLR2K    GTF2H3
# HALLMARK_G2M_CHECKPOINT                        CDC20      PLK1       TTK
# HALLMARK_APOPTOSIS                            PMAIP1     CASP8       JUN
# HALLMARK_NOTCH_SIGNALING                        FZD1     PSEN2      FZD7
# HALLMARK_ADIPOGENESIS                           CPT2      CD36      GPAM
# HALLMARK_ESTROGEN_RESPONSE_EARLY                SYBU     NPY1R     PDZK1
# HALLMARK_ESTROGEN_RESPONSE_LATE                ANXA9    CELSR2      TJP3
# HALLMARK_ANDROGEN_RESPONSE                   TMPRSS2    APPBP2     CENPN
# HALLMARK_MYOGENESIS                            MYLPF     TNNT3     TNNT2
# HALLMARK_PROTEIN_SECRETION                     LAMP2      EGFR     IGF2R
# HALLMARK_INTERFERON_ALPHA_RESPONSE              IRF7     RSAD2    IFI44L
# HALLMARK_INTERFERON_GAMMA_RESPONSE              IRF7     IFIT2      OAS2
# HALLMARK_APICAL_JUNCTION                     COL17A1   NECTIN1     CLDN9
# HALLMARK_APICAL_SURFACE                       CRYBG1   SHROOM2      SRPX
# HALLMARK_HEDGEHOG_SIGNALING                    UNC5C    ADGRG1      HEY1
# HALLMARK_COMPLEMENT                         SERPING1      CTSL        F5
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE            EXOSC9     HSPA5      ATF3
# HALLMARK_PI3K_AKT_MTOR_SIGNALING                AKT1     MAPK1     PLCG1
# HALLMARK_MTORC1_SIGNALING                       CTSC     ACSL3    SLC1A5
# HALLMARK_E2F_TARGETS                           DNMT1    DONSON       EED
# HALLMARK_MYC_TARGETS_V1                        SRSF2     G3BP1    STARD7
# HALLMARK_MYC_TARGETS_V2                       EXOSC5      IPO4   NDUFAF4
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION    COL6A3  SERPINE1    COL1A2
# HALLMARK_INFLAMMATORY_RESPONSE                 CXCL8      CCL7     CCL22
# HALLMARK_XENOBIOTIC_METABOLISM               CYP27A1     ADH1C      UGDH
# HALLMARK_FATTY_ACID_METABOLISM                 ACSL1   ALDH3A2    CCDC58
# HALLMARK_OXIDATIVE_PHOSPHORYLATION            NDUFS4    NDUFS1    NDUFA2
# HALLMARK_GLYCOLYSIS                            ALDOB     VEGFA      MXI1
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY        GPX4       MPO     PRDX1
# HALLMARK_P53_PATHWAY                         GADD45A    PHLDA3      TAP1
# HALLMARK_UV_RESPONSE_UP                        ALAS1    TUBA4A     C4BPB
# HALLMARK_UV_RESPONSE_DN                       MAP2K5     AGGF1     PLCB4
# HALLMARK_ANGIOGENESIS                          VEGFA       PF4      THBD
# HALLMARK_HEME_METABOLISM                         RHD      GYPA  SELENBP1
# HALLMARK_COAGULATION                             C1R  SERPINE1  SERPING1
# HALLMARK_IL2_STAT5_SIGNALING                 TNFRSF9      XBP1     RRAGD
# HALLMARK_BILE_ACID_METABOLISM                  ABCD2      PEX1    CYP8B1
# HALLMARK_PEROXISOME                           EHHADH     GSTK1   HSD17B4
# HALLMARK_ALLOGRAFT_REJECTION                    CD28       LYN     HCLS1
# HALLMARK_SPERMATOGENESIS                      ACTL7B    GAPDHS    TUBA3C
# HALLMARK_KRAS_SIGNALING_UP                      ETV4      GLRX     DUSP6
# HALLMARK_KRAS_SIGNALING_DN                      NTF3    SCN10A    TAS2R4
# HALLMARK_PANCREAS_BETA_CELLS                  SLC2A2    SEC11A       DCX
#
#                                                 11   ...      192       193  \
# 0                                                    ...
# HALLMARK_TNFA_SIGNALING_VIA_NFKB              CCL20  ...     EIF1      BMP2
# HALLMARK_HYPOXIA                              ALDOC  ...    HDLBP     ILVBL
# HALLMARK_CHOLESTEROL_HOMEOSTASIS                MVD  ...      NaN       NaN
# HALLMARK_MITOTIC_SPINDLE                      CKAP5  ...   SORBS2  CDC42EP1
# HALLMARK_WNT_BETA_CATENIN_SIGNALING            LEF1  ...      NaN       NaN
# HALLMARK_TGF_BETA_SIGNALING                  PMEPA1  ...      NaN       NaN
# HALLMARK_IL6_JAK_STAT3_SIGNALING             IFNGR1  ...      NaN       NaN
# HALLMARK_DNA_REPAIR                          POLR2D  ...      NaN       NaN
# HALLMARK_G2M_CHECKPOINT                        PRC1  ...    KIF5B      MTF2
# HALLMARK_APOPTOSIS                          BCL2L11  ...      NaN       NaN
# HALLMARK_NOTCH_SIGNALING                       DTX1  ...      NaN       NaN
# HALLMARK_ADIPOGENESIS                       ADIPOR2  ...   MAP4K3    ANGPT1
# HALLMARK_ESTROGEN_RESPONSE_EARLY              NRIP1  ...  ALDH3B1     THSD4
# HALLMARK_ESTROGEN_RESPONSE_LATE                 PGR  ...      TST     TOP2A
# HALLMARK_ANDROGEN_RESPONSE                   BMPR1B  ...      NaN       NaN
# HALLMARK_MYOGENESIS                           CASQ2  ...   COL6A2      DTNA
# HALLMARK_PROTEIN_SECRETION                     COPE  ...      NaN       NaN
# HALLMARK_INTERFERON_ALPHA_RESPONSE           IFITM1  ...      NaN       NaN
# HALLMARK_INTERFERON_GAMMA_RESPONSE             TAP1  ...  METTL7B   ST8SIA4
# HALLMARK_APICAL_JUNCTION                       CDH3  ...    SYMPK      STX4
# HALLMARK_APICAL_SURFACE                       MDGA1  ...      NaN       NaN
# HALLMARK_HEDGEHOG_SIGNALING                    GLI1  ...      NaN       NaN
# HALLMARK_COMPLEMENT                           MMP13  ...   ADRA2B     CEBPB
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE           EXOSC1  ...      NaN       NaN
# HALLMARK_PI3K_AKT_MTOR_SIGNALING              TRIB3  ...      NaN       NaN
# HALLMARK_MTORC1_SIGNALING                      M6PR  ...     HMBS      RIT1
# HALLMARK_E2F_TARGETS                          GINS1  ...      AK2       CIT
# HALLMARK_MYC_TARGETS_V1                        NPM1  ...    SRSF7      GNL3
# HALLMARK_MYC_TARGETS_V2                       NOC4L  ...      NaN       NaN
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION   COL4A1  ...     BDNF    ADAM12
# HALLMARK_INFLAMMATORY_RESPONSE               CXCL11  ...  SELENOS       LTA
# HALLMARK_XENOBIOTIC_METABOLISM                  ASL  ...   PDLIM5    CYP2E1
# HALLMARK_FATTY_ACID_METABOLISM                 CPT2  ...      NaN       NaN
# HALLMARK_OXIDATIVE_PHOSPHORYLATION           NDUFS8  ...     ECH1     RHOT2
# HALLMARK_GLYCOLYSIS                             PKM  ...    MERTK      GCLC
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY      PRDX6  ...      NaN       NaN
# HALLMARK_P53_PATHWAY                         CDKN2B  ...    NHLH2    BAIAP2
# HALLMARK_UV_RESPONSE_UP                       CCNE1  ...      NaN       NaN
# HALLMARK_UV_RESPONSE_DN                         MET  ...      NaN       NaN
# HALLMARK_ANGIOGENESIS                         FGFR1  ...      NaN       NaN
# HALLMARK_HEME_METABOLISM                      BLVRB  ...   ARL2BP    ENDOD1
# HALLMARK_COAGULATION                             C2  ...      NaN       NaN
# HALLMARK_IL2_STAT5_SIGNALING                    HK2  ...    LRIG1    SWAP70
# HALLMARK_BILE_ACID_METABOLISM                PNPLA8  ...      NaN       NaN
# HALLMARK_PEROXISOME                           MLYCD  ...      NaN       NaN
# HALLMARK_ALLOGRAFT_REJECTION                   IL18  ...    CCL13     RPL3L
# HALLMARK_SPERMATOGENESIS                       LDHC  ...      NaN       NaN
# HALLMARK_KRAS_SIGNALING_UP                     SCG5  ...    WDR33      MYCN
# HALLMARK_KRAS_SIGNALING_DN                     DTNB  ...   ZNF112    TFAP2B
# HALLMARK_PANCREAS_BETA_CELLS                  SPCS1  ...      NaN       NaN
#
#                                                 194       195      196  \
# 0
# HALLMARK_TNFA_SIGNALING_VIA_NFKB              DUSP4    PDLIM5   ICOSLG
# HALLMARK_HYPOXIA                               NCAN      TGM2     ETS1
# HALLMARK_CHOLESTEROL_HOMEOSTASIS                NaN       NaN      NaN
# HALLMARK_MITOTIC_SPINDLE                        VCL     CLIP1   STK38L
# HALLMARK_WNT_BETA_CATENIN_SIGNALING             NaN       NaN      NaN
# HALLMARK_TGF_BETA_SIGNALING                     NaN       NaN      NaN
# HALLMARK_IL6_JAK_STAT3_SIGNALING                NaN       NaN      NaN
# HALLMARK_DNA_REPAIR                             NaN       NaN      NaN
# HALLMARK_G2M_CHECKPOINT                        E2F4      BCL3     PURA
# HALLMARK_APOPTOSIS                              NaN       NaN      NaN
# HALLMARK_NOTCH_SIGNALING                        NaN       NaN      NaN
# HALLMARK_ADIPOGENESIS                        UBQLN1    NDUFB7  SLC19A1
# HALLMARK_ESTROGEN_RESPONSE_EARLY              CLIC3      NXT1     NAV2
# HALLMARK_ESTROGEN_RESPONSE_LATE                 CKB       LTF    DUSP2
# HALLMARK_ANDROGEN_RESPONSE                      NaN       NaN      NaN
# HALLMARK_MYOGENESIS                           KIFC3     SPARC    SPDEF
# HALLMARK_PROTEIN_SECRETION                      NaN       NaN      NaN
# HALLMARK_INTERFERON_ALPHA_RESPONSE              NaN       NaN      NaN
# HALLMARK_INTERFERON_GAMMA_RESPONSE             XCL1     IL2RB    VAMP5
# HALLMARK_APICAL_JUNCTION                     PECAM1   MADCAM1    ITGA9
# HALLMARK_APICAL_SURFACE                         NaN       NaN      NaN
# HALLMARK_HEDGEHOG_SIGNALING                     NaN       NaN      NaN
# HALLMARK_COMPLEMENT                           HNF4A    LGALS3  TNFAIP3
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE              NaN       NaN      NaN
# HALLMARK_PI3K_AKT_MTOR_SIGNALING                NaN       NaN      NaN
# HALLMARK_MTORC1_SIGNALING                     SKAP2     STIP1    DAPP1
# HALLMARK_E2F_TARGETS                           ING3      JPT1     POP7
# HALLMARK_MYC_TARGETS_V1                      EXOSC7    MRPL23   RAD23B
# HALLMARK_MYC_TARGETS_V2                         NaN       NaN      NaN
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION      PVR    CXCL12   PDGFRB
# HALLMARK_INFLAMMATORY_RESPONSE               PIK3R5     STAB1     IRF1
# HALLMARK_XENOBIOTIC_METABOLISM                BCAT1     ATOH8   SLC1A5
# HALLMARK_FATTY_ACID_METABOLISM                  NaN       NaN      NaN
# HALLMARK_OXIDATIVE_PHOSPHORYLATION              BAX     MTRF1    GLUD1
# HALLMARK_GLYCOLYSIS                           FKBP4      SOD1    MED24
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY        NaN       NaN      NaN
# HALLMARK_P53_PATHWAY                         RETSAT      LRMP     H1-2
# HALLMARK_UV_RESPONSE_UP                         NaN       NaN      NaN
# HALLMARK_UV_RESPONSE_DN                         NaN       NaN      NaN
# HALLMARK_ANGIOGENESIS                           NaN       NaN      NaN
# HALLMARK_HEME_METABOLISM                      P4HA2   HTATIP2  SLC7A11
# HALLMARK_COAGULATION                            NaN       NaN      NaN
# HALLMARK_IL2_STAT5_SIGNALING                SLC39A8  RABGAP1L     TGM2
# HALLMARK_BILE_ACID_METABOLISM                   NaN       NaN      NaN
# HALLMARK_PEROXISOME                             NaN       NaN      NaN
# HALLMARK_ALLOGRAFT_REJECTION                   LY75     TAPBP     NOS2
# HALLMARK_SPERMATOGENESIS                        NaN       NaN      NaN
# HALLMARK_KRAS_SIGNALING_UP                   FCER1G    PECAM1   CCSER2
# HALLMARK_KRAS_SIGNALING_DN                    VPS50      CD80    ATP4A
# HALLMARK_PANCREAS_BETA_CELLS                    NaN       NaN      NaN
#
#                                                 197       198         199  \
# 0
# HALLMARK_TNFA_SIGNALING_VIA_NFKB              GFPT2      KLF2         TNC
# HALLMARK_HYPOXIA                              HOXB9  SELENBP1       FOSL2
# HALLMARK_CHOLESTEROL_HOMEOSTASIS                NaN       NaN         NaN
# HALLMARK_MITOTIC_SPINDLE                      YWHAE   RAPGEF5       CEP72
# HALLMARK_WNT_BETA_CATENIN_SIGNALING             NaN       NaN         NaN
# HALLMARK_TGF_BETA_SIGNALING                     NaN       NaN         NaN
# HALLMARK_IL6_JAK_STAT3_SIGNALING                NaN       NaN         NaN
# HALLMARK_DNA_REPAIR                             NaN       NaN         NaN
# HALLMARK_G2M_CHECKPOINT                       MEIS2  PAFAH1B1         WRN
# HALLMARK_APOPTOSIS                              NaN       NaN         NaN
# HALLMARK_NOTCH_SIGNALING                        NaN       NaN         NaN
# HALLMARK_ADIPOGENESIS                         ABCB8   SLC66A3         POR
# HALLMARK_ESTROGEN_RESPONSE_EARLY              RRP12     ADCY1       DHCR7
# HALLMARK_ESTROGEN_RESPONSE_LATE               PTPN6    ATP2B4  ST6GALNAC2
# HALLMARK_ANDROGEN_RESPONSE                      NaN       NaN         NaN
# HALLMARK_MYOGENESIS                             SLN     WWTR1        CD36
# HALLMARK_PROTEIN_SECRETION                      NaN       NaN         NaN
# HALLMARK_INTERFERON_ALPHA_RESPONSE              NaN       NaN         NaN
# HALLMARK_INTERFERON_GAMMA_RESPONSE           IL18BP     ZNFX1      ARID5B
# HALLMARK_APICAL_JUNCTION                       CD86       TRO       CLDN5
# HALLMARK_APICAL_SURFACE                         NaN       NaN         NaN
# HALLMARK_HEDGEHOG_SIGNALING                     NaN       NaN         NaN
# HALLMARK_COMPLEMENT                           CDH13     ITIH1       TFPI2
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE              NaN       NaN         NaN
# HALLMARK_PI3K_AKT_MTOR_SIGNALING                NaN       NaN         NaN
# HALLMARK_MTORC1_SIGNALING                     ABCF2      NFYC     ATP5MC1
# HALLMARK_E2F_TARGETS                        SYNCRIP    EIF2S1        LYAR
# HALLMARK_MYC_TARGETS_V1                       RPS10       PHB       DDX21
# HALLMARK_MYC_TARGETS_V2                         NaN       NaN         NaN
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION    SLIT2    NOTCH2    COLGALT1
# HALLMARK_INFLAMMATORY_RESPONSE                ICAM4     P2RX4        ABI1
# HALLMARK_XENOBIOTIC_METABOLISM                 IRF8     NINJ1       AP4B1
# HALLMARK_FATTY_ACID_METABOLISM                  NaN       NaN         NaN
# HALLMARK_OXIDATIVE_PHOSPHORYLATION          SUPV3L1    GRPEL1        PDP1
# HALLMARK_GLYCOLYSIS                             AK3     XYLT2        ARTN
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY        NaN       NaN         NaN
# HALLMARK_P53_PATHWAY                        DNTTIP2      MXD4     SEC61A1
# HALLMARK_UV_RESPONSE_UP                         NaN       NaN         NaN
# HALLMARK_UV_RESPONSE_DN                         NaN       NaN         NaN
# HALLMARK_ANGIOGENESIS                           NaN       NaN         NaN
# HALLMARK_HEME_METABOLISM                      KHNYN    MBOAT2    ATP6V0A1
# HALLMARK_COAGULATION                            NaN       NaN         NaN
# HALLMARK_IL2_STAT5_SIGNALING                    PNP      AGER        ETV4
# HALLMARK_BILE_ACID_METABOLISM                   NaN       NaN         NaN
# HALLMARK_PEROXISOME                             NaN       NaN         NaN
# HALLMARK_ALLOGRAFT_REJECTION                   RPL9     BCAT1         IL9
# HALLMARK_SPERMATOGENESIS                        NaN       NaN         NaN
# HALLMARK_KRAS_SIGNALING_UP                   SNAP91      EVI5    TNFRSF1B
# HALLMARK_KRAS_SIGNALING_DN                   ARPP21  SERPINB2        TLX1
# HALLMARK_PANCREAS_BETA_CELLS                    NaN       NaN         NaN
#
#                                                  200      201
# 0
# HALLMARK_TNFA_SIGNALING_VIA_NFKB            SERPINB8     MXD1
# HALLMARK_HYPOXIA                             SULT2B1    TGFB3
# HALLMARK_CHOLESTEROL_HOMEOSTASIS                 NaN      NaN
# HALLMARK_MITOTIC_SPINDLE                      CSNK1D      NaN
# HALLMARK_WNT_BETA_CATENIN_SIGNALING              NaN      NaN
# HALLMARK_TGF_BETA_SIGNALING                      NaN      NaN
# HALLMARK_IL6_JAK_STAT3_SIGNALING                 NaN      NaN
# HALLMARK_DNA_REPAIR                              NaN      NaN
# HALLMARK_G2M_CHECKPOINT                        H2AZ2     ODF2
# HALLMARK_APOPTOSIS                               NaN      NaN
# HALLMARK_NOTCH_SIGNALING                         NaN      NaN
# HALLMARK_ADIPOGENESIS                           UCP2   UQCR11
# HALLMARK_ESTROGEN_RESPONSE_EARLY                MICB    AKAP1
# HALLMARK_ESTROGEN_RESPONSE_LATE                 ADD3   DYNLT3
# HALLMARK_ANDROGEN_RESPONSE                       NaN      NaN
# HALLMARK_MYOGENESIS                            ADCY9     APOD
# HALLMARK_PROTEIN_SECRETION                       NaN      NaN
# HALLMARK_INTERFERON_ALPHA_RESPONSE               NaN      NaN
# HALLMARK_INTERFERON_GAMMA_RESPONSE             APOL6    STAT4
# HALLMARK_APICAL_JUNCTION                       MPZL1     WASL
# HALLMARK_APICAL_SURFACE                          NaN      NaN
# HALLMARK_HEDGEHOG_SIGNALING                      NaN      NaN
# HALLMARK_COMPLEMENT                           PIK3CG  S100A13
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE               NaN      NaN
# HALLMARK_PI3K_AKT_MTOR_SIGNALING                 NaN      NaN
# HALLMARK_MTORC1_SIGNALING                       PFKL    CCT6A
# HALLMARK_E2F_TARGETS                            PAN2    SPC24
# HALLMARK_MYC_TARGETS_V1                         CYC1   PABPC1
# HALLMARK_MYC_TARGETS_V2                          NaN      NaN
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION      GPX7    WIPF1
# HALLMARK_INFLAMMATORY_RESPONSE                CX3CL1  SLC28A2
# HALLMARK_XENOBIOTIC_METABOLISM                 ACSM1    ITIH1
# HALLMARK_FATTY_ACID_METABOLISM                   NaN      NaN
# HALLMARK_OXIDATIVE_PHOSPHORYLATION           ALDH6A1      OAT
# HALLMARK_GLYCOLYSIS                             PPIA    CHST4
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY         NaN      NaN
# HALLMARK_P53_PATHWAY                           HMOX1    RAD9A
# HALLMARK_UV_RESPONSE_UP                          NaN      NaN
# HALLMARK_UV_RESPONSE_DN                          NaN      NaN
# HALLMARK_ANGIOGENESIS                            NaN      NaN
# HALLMARK_HEME_METABOLISM                        CAST      TYR
# HALLMARK_COAGULATION                             NaN      NaN
# HALLMARK_IL2_STAT5_SIGNALING                    CD86      NaN
# HALLMARK_BILE_ACID_METABOLISM                    NaN      NaN
# HALLMARK_PEROXISOME                              NaN      NaN
# HALLMARK_ALLOGRAFT_REJECTION                  IL27RA    DYRK3
# HALLMARK_SPERMATOGENESIS                         NaN      NaN
# HALLMARK_KRAS_SIGNALING_UP                     GPNMB     TPH1
# HALLMARK_KRAS_SIGNALING_DN                     EFHD1    P2RY4
# HALLMARK_PANCREAS_BETA_CELLS                     NaN      NaN
#
# [50 rows x 200 columns]

# %%
import gsea

# %% [markdown]
# ## Single sample GSEA

# %%
en_se_sa = gsea.run_single_sample_gsea(
    sc_ge_sa,  # Gene-by-sample score; DataFrame
    gm,  # Gene sets; set-to-genes dict or DataFrame
    no="-0-",  # Normalization method; "-0-", "0-1", "1234", "log"
    mi=5,  # Minimum gene set size; int
    ma=500,  # Maximum gene set size; int
    we=1.0,  # Weight used for "ks" and "auc"; float
    me="ks",  # Enrichment method; "ks", "auc", "js"
    pa="single_sample_gsea.tsv",  # .tsv file path to write the gene-set-by-sample output; str
)

en_se_sa
# Out:
# Normalized each sample (method -0-).
# Selected 50 gene sets (5 <= size <= 500).
#                                             BRAF-MAPK       EMT  HNF1-PAX8  \
# Set
# HALLMARK_ANGIOGENESIS                        0.757748 -0.679977   0.487706
# HALLMARK_MYOGENESIS                          0.482133 -0.377984   0.432781
# HALLMARK_PEROXISOME                         -0.336643 -0.337661  -0.761044
# HALLMARK_UV_RESPONSE_DN                      0.322993 -0.322111  -0.271277
# HALLMARK_NOTCH_SIGNALING                    -0.635801  0.789579   0.695391
# HALLMARK_ANDROGEN_RESPONSE                   0.369478 -0.501558   0.306185
# HALLMARK_ALLOGRAFT_REJECTION                 0.448666 -0.620565  -0.231082
# HALLMARK_ESTROGEN_RESPONSE_LATE             -0.258763 -0.219849  -0.382965
# HALLMARK_G2M_CHECKPOINT                      0.667102 -0.434252   0.410842
# HALLMARK_MYC_TARGETS_V2                      0.784353 -0.510998  -0.449298
# HALLMARK_APOPTOSIS                           0.594956 -0.482858  -0.241042
# HALLMARK_P53_PATHWAY                         0.163968  0.249515   0.409942
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE           0.724900 -0.397676  -0.435977
# HALLMARK_ADIPOGENESIS                       -0.480529 -0.640225  -0.684428
# HALLMARK_DNA_REPAIR                          0.761377  0.447723   0.413462
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION   0.441069 -0.334012  -0.243559
# HALLMARK_OXIDATIVE_PHOSPHORYLATION           0.879518 -0.560861   0.541579
# HALLMARK_HEME_METABOLISM                     0.421264 -0.423367   0.523763
# HALLMARK_MITOTIC_SPINDLE                     0.566721  0.457124  -0.428877
# HALLMARK_FATTY_ACID_METABOLISM               0.586815 -0.803607   0.401486
# HALLMARK_COMPLEMENT                          0.525229  0.408996  -0.256742
# HALLMARK_APICAL_SURFACE                      0.686564 -0.914752  -0.698397
# HALLMARK_ESTROGEN_RESPONSE_EARLY            -0.240633  0.175452  -0.230822
# HALLMARK_INTERFERON_GAMMA_RESPONSE           0.227206  0.440323   0.294139
# HALLMARK_MTORC1_SIGNALING                    0.647133  0.434981  -0.436824
# HALLMARK_INTERFERON_ALPHA_RESPONSE           0.215726  0.435935  -0.293458
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY     0.601805 -0.274824  -0.495264
# HALLMARK_PI3K_AKT_MTOR_SIGNALING             0.810811  0.938939   0.615616
# HALLMARK_XENOBIOTIC_METABOLISM               0.422248  0.346600   0.298733
# HALLMARK_KRAS_SIGNALING_DN                  -0.300883  0.410968  -0.161532
# HALLMARK_UV_RESPONSE_UP                      0.621106 -0.702394   0.380854
# HALLMARK_WNT_BETA_CATENIN_SIGNALING         -0.329990  0.307955   0.638917
# HALLMARK_PROTEIN_SECRETION                   0.646018 -0.597793  -0.311552
# HALLMARK_IL2_STAT5_SIGNALING                 0.424382 -0.364572   0.491907
# HALLMARK_TNFA_SIGNALING_VIA_NFKB             0.620634 -0.284775   0.274429
# HALLMARK_MYC_TARGETS_V1                      0.934804 -0.467956  -0.713239
# HALLMARK_APICAL_JUNCTION                    -0.334717  0.155277   0.232369
# HALLMARK_E2F_TARGETS                         0.852558 -0.371801  -0.323709
# HALLMARK_SPERMATOGENESIS                     0.392928 -0.630399   0.634349
# HALLMARK_BILE_ACID_METABOLISM               -0.717681  0.485007  -0.809779
# HALLMARK_KRAS_SIGNALING_UP                   0.756780 -0.412697   0.237687
# HALLMARK_INFLAMMATORY_RESPONSE               0.360411 -0.472491  -0.347248
# HALLMARK_CHOLESTEROL_HOMEOSTASIS             0.558902 -0.230112  -0.433440
# HALLMARK_TGF_BETA_SIGNALING                  0.609670 -0.444984  -0.334594
# HALLMARK_PANCREAS_BETA_CELLS                 0.346782  0.509413  -0.689105
# HALLMARK_COAGULATION                         0.597804  0.349078  -0.517708
# HALLMARK_HYPOXIA                             0.319543 -0.483471  -0.226151
# HALLMARK_GLYCOLYSIS                          0.318936 -0.416028  -0.438695
# HALLMARK_HEDGEHOG_SIGNALING                  0.333333 -0.550716   0.385542
# HALLMARK_IL6_JAK_STAT3_SIGNALING             0.440427 -0.608923   0.362892
#
#                                              MYC-E2F  RAS-WNT-PI3K  KRAS-AP1  \
# Set
# HALLMARK_ANGIOGENESIS                      -0.635908     -0.331590 -0.444349
# HALLMARK_MYOGENESIS                         0.214575     -0.338818 -0.384358
# HALLMARK_PEROXISOME                        -0.593931      0.398097 -0.668548
# HALLMARK_UV_RESPONSE_DN                    -0.401123      0.515288 -0.463534
# HALLMARK_NOTCH_SIGNALING                   -0.720397     -0.698965 -0.653307
# HALLMARK_ANDROGEN_RESPONSE                 -0.316382      0.562271  0.379405
# HALLMARK_ALLOGRAFT_REJECTION               -0.500913     -0.381885  0.277966
# HALLMARK_ESTROGEN_RESPONSE_LATE             0.256227     -0.395508 -0.274415
# HALLMARK_G2M_CHECKPOINT                    -0.225858      0.654698 -0.271339
# HALLMARK_MYC_TARGETS_V2                     0.405009      0.386854 -0.559222
# HALLMARK_APOPTOSIS                         -0.499600     -0.352687  0.236929
# HALLMARK_P53_PATHWAY                       -0.294261     -0.452382  0.379761
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE         -0.745984     -0.324118 -0.560104
# HALLMARK_ADIPOGENESIS                      -0.740309     -0.499298 -0.858717
# HALLMARK_DNA_REPAIR                         0.431266      0.408216 -0.399984
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  0.261613     -0.316641 -0.293317
# HALLMARK_OXIDATIVE_PHOSPHORYLATION          0.443611      0.447163 -0.466127
# HALLMARK_HEME_METABOLISM                    0.470880      0.719068 -0.437687
# HALLMARK_MITOTIC_SPINDLE                   -0.438030     -0.429870 -0.363137
# HALLMARK_FATTY_ACID_METABOLISM             -0.513332      0.720516  0.858942
# HALLMARK_COMPLEMENT                         0.411521      0.296183 -0.343385
# HALLMARK_APICAL_SURFACE                     0.641394      0.575150  0.712425
# HALLMARK_ESTROGEN_RESPONSE_EARLY            0.227892     -0.371117 -0.235414
# HALLMARK_INTERFERON_GAMMA_RESPONSE         -0.402279     -0.470355 -0.410744
# HALLMARK_MTORC1_SIGNALING                  -0.386374     -0.425579 -0.295906
# HALLMARK_INTERFERON_ALPHA_RESPONSE         -0.298039     -0.511942 -0.449582
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY    0.608199     -0.316095 -0.536774
# HALLMARK_PI3K_AKT_MTOR_SIGNALING            0.762763     -0.754755 -0.805806
# HALLMARK_XENOBIOTIC_METABOLISM             -0.204908     -0.543300 -0.296691
# HALLMARK_KRAS_SIGNALING_DN                  0.336536     -0.311827  0.332921
# HALLMARK_UV_RESPONSE_UP                     0.632999      0.415915 -0.557799
# HALLMARK_WNT_BETA_CATENIN_SIGNALING        -0.834504     -0.594948 -0.630854
# HALLMARK_PROTEIN_SECRETION                 -0.739250      0.501577 -0.708124
# HALLMARK_IL2_STAT5_SIGNALING                0.305699     -0.377980 -0.219060
# HALLMARK_TNFA_SIGNALING_VIA_NFKB           -0.425613     -0.356068 -0.300945
# HALLMARK_MYC_TARGETS_V1                     0.428385      0.375430 -0.702182
# HALLMARK_APICAL_JUNCTION                   -0.229434      0.286812 -0.230696
# HALLMARK_E2F_TARGETS                       -0.624190      0.684052 -0.607052
# HALLMARK_SPERMATOGENESIS                   -0.700917      0.764445 -0.460765
# HALLMARK_BILE_ACID_METABOLISM               0.282849      0.627629 -0.479213
# HALLMARK_KRAS_SIGNALING_UP                  0.204029     -0.297708  0.195150
# HALLMARK_INFLAMMATORY_RESPONSE             -0.408590     -0.412472 -0.376021
# HALLMARK_CHOLESTEROL_HOMEOSTASIS            0.510343     -0.406370 -0.501200
# HALLMARK_TGF_BETA_SIGNALING                -0.314591     -0.457498 -0.323889
# HALLMARK_PANCREAS_BETA_CELLS               -0.404213      0.499573 -0.754263
# HALLMARK_COAGULATION                        0.295428      0.300030  0.288634
# HALLMARK_HYPOXIA                           -0.360984     -0.233792 -0.325435
# HALLMARK_GLYCOLYSIS                        -0.362832     -0.250792 -0.264017
# HALLMARK_HEDGEHOG_SIGNALING                -0.524129      0.292012 -0.514329
# HALLMARK_IL6_JAK_STAT3_SIGNALING           -0.490998     -0.838516 -0.352900
#
#                                             TNF-NFKB-YAP       MYC  ERBB3-PI3K
# Set
# HALLMARK_ANGIOGENESIS                          -0.337170 -0.539267    0.285808
# HALLMARK_MYOGENESIS                             0.160764 -0.286942   -0.329925
# HALLMARK_PEROXISOME                             0.295181  0.402999    0.387851
# HALLMARK_UV_RESPONSE_DN                        -0.258525  0.207541    0.198783
# HALLMARK_NOTCH_SIGNALING                       -0.686373  0.569138    0.437876
# HALLMARK_ANDROGEN_RESPONSE                      0.484614 -0.697424   -0.509572
# HALLMARK_ALLOGRAFT_REJECTION                   -0.444252 -0.286075   -0.465723
# HALLMARK_ESTROGEN_RESPONSE_LATE                 0.260424 -0.270422    0.310410
# HALLMARK_G2M_CHECKPOINT                        -0.397287  0.385466    0.495129
# HALLMARK_MYC_TARGETS_V2                         0.678332  0.549303   -0.748549
# HALLMARK_APOPTOSIS                             -0.378121 -0.488525    0.374099
# HALLMARK_P53_PATHWAY                            0.270466  0.295932   -0.227868
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE              0.527844  0.479920   -0.325301
# HALLMARK_ADIPOGENESIS                           0.916066  0.457364    0.308617
# HALLMARK_DNA_REPAIR                            -0.352828 -0.395284   -0.495547
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION      0.239747 -0.309518    0.454229
# HALLMARK_OXIDATIVE_PHOSPHORYLATION             -0.487362 -0.748155   -0.456898
# HALLMARK_HEME_METABOLISM                       -0.683901  0.420261    0.436987
# HALLMARK_MITOTIC_SPINDLE                        0.499795  0.330653    0.412190
# HALLMARK_FATTY_ACID_METABOLISM                  0.978470  0.792553   -0.629259
# HALLMARK_COMPLEMENT                            -0.194186  0.215148    0.288796
# HALLMARK_APICAL_SURFACE                         0.644289  0.428065    0.296593
# HALLMARK_ESTROGEN_RESPONSE_EARLY                0.299161  0.230894    0.340799
# HALLMARK_INTERFERON_GAMMA_RESPONSE              0.341230 -0.282458   -0.206287
# HALLMARK_MTORC1_SIGNALING                      -0.332152 -0.572806   -0.674277
# HALLMARK_INTERFERON_ALPHA_RESPONSE              0.332722 -0.394573    0.359092
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY       -0.784353  0.664026   -0.725176
# HALLMARK_PI3K_AKT_MTOR_SIGNALING               -0.658659 -0.637638   -0.964965
# HALLMARK_XENOBIOTIC_METABOLISM                  0.391534  0.544997   -0.306410
# HALLMARK_KRAS_SIGNALING_DN                     -0.309242 -0.250255    0.372228
# HALLMARK_UV_RESPONSE_UP                        -0.512948 -0.353903   -0.340746
# HALLMARK_WNT_BETA_CATENIN_SIGNALING            -0.436161 -0.298211   -0.694941
# HALLMARK_PROTEIN_SECRETION                     -0.459120 -0.586793    0.441347
# HALLMARK_IL2_STAT5_SIGNALING                   -0.400634  0.235123    0.352194
# HALLMARK_TNFA_SIGNALING_VIA_NFKB               -0.253993  0.267306    0.413002
# HALLMARK_MYC_TARGETS_V1                        -0.528586 -0.348044   -0.625348
# HALLMARK_APICAL_JUNCTION                        0.259483  0.221606   -0.237969
# HALLMARK_E2F_TARGETS                            0.497762  0.573721   -0.698514
# HALLMARK_SPERMATOGENESIS                       -0.762287 -0.394377   -0.551655
# HALLMARK_BILE_ACID_METABOLISM                  -0.460055 -0.620373    0.395541
# HALLMARK_KRAS_SIGNALING_UP                     -0.293046  0.352172    0.252755
# HALLMARK_INFLAMMATORY_RESPONSE                 -0.246505 -0.225274   -0.259434
# HALLMARK_CHOLESTEROL_HOMEOSTASIS               -0.330653  0.284422    0.503054
# HALLMARK_TGF_BETA_SIGNALING                    -0.464581 -0.418001   -0.596425
# HALLMARK_PANCREAS_BETA_CELLS                   -0.649950 -0.550441    0.650272
# HALLMARK_COAGULATION                           -0.260827  0.305485   -0.376760
# HALLMARK_HYPOXIA                               -0.472730  0.178192    0.369518
# HALLMARK_GLYCOLYSIS                            -0.447031 -0.203237    0.406801
# HALLMARK_HEDGEHOG_SIGNALING                    -0.510345 -0.442752    0.376077
# HALLMARK_IL6_JAK_STAT3_SIGNALING               -0.675953  0.533684    0.577124

# %% [markdown]
# ## Prerank GSEA

# %%
ge_sc = sc_ge_sa.iloc[:, 0]

nu_se_st = gsea.run_prerank_gsea(
    ge_sc,  # Gene scores; Series
    gm,  # Gene sets; set-to-genes dict or DataFrame
    mi=5,  # Minimum gene set size; int
    ma=500,  # Maximum gene set size; int
    we=1,  # Weight used for "ks" and "auc"; float
    me="ks",  # Enrichment method; "ks", "auc", "js"
    se=1729,  # Random seed; int
    pe="label",  # Permutation type; "gene_set"
    n_pe=1000,  # Number of permutations; int
    n_pl=25,  # Number of extreme gene sets to plot; int
    ad=None,  # Additional gene sets to plot; list of str
    pa="~/Downloads/",  # directory path to write the gene-set-by-statistic and plots; str
)

nu_se_st
# Out:
# Selected 50 gene sets (5 <= size <= 500).
#                                             Enrichment P-Value Q-Value
# HALLMARK_ADIPOGENESIS                         0.497137    None    None
# HALLMARK_ALLOGRAFT_REJECTION                  0.325851    None    None
# HALLMARK_ANDROGEN_RESPONSE                   -0.384579    None    None
# HALLMARK_ANGIOGENESIS                         0.621929    None    None
# HALLMARK_APICAL_JUNCTION                     -0.448524    None    None
# HALLMARK_APICAL_SURFACE                       0.779845    None    None
# HALLMARK_APOPTOSIS                            0.248485    None    None
# HALLMARK_BILE_ACID_METABOLISM                -0.733649    None    None
# HALLMARK_CHOLESTEROL_HOMEOSTASIS             -0.350380    None    None
# HALLMARK_COAGULATION                         -0.208196    None    None
# HALLMARK_COMPLEMENT                          -0.300341    None    None
# HALLMARK_DNA_REPAIR                          -0.354774    None    None
# HALLMARK_E2F_TARGETS                          0.432297    None    None
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION    0.136472    None    None
# HALLMARK_ESTROGEN_RESPONSE_EARLY              0.107170    None    None
# HALLMARK_ESTROGEN_RESPONSE_LATE               0.197152    None    None
# HALLMARK_FATTY_ACID_METABOLISM                0.418838    None    None
# HALLMARK_G2M_CHECKPOINT                      -0.269812    None    None
# HALLMARK_GLYCOLYSIS                          -0.229824    None    None
# HALLMARK_HEDGEHOG_SIGNALING                   0.228338    None    None
# HALLMARK_HEME_METABOLISM                     -0.488267    None    None
# HALLMARK_HYPOXIA                              0.281887    None    None
# HALLMARK_IL2_STAT5_SIGNALING                  0.184425    None    None
# HALLMARK_IL6_JAK_STAT3_SIGNALING              0.446339    None    None
# HALLMARK_INFLAMMATORY_RESPONSE               -0.200945    None    None
# HALLMARK_INTERFERON_ALPHA_RESPONSE            0.233878    None    None
# HALLMARK_INTERFERON_GAMMA_RESPONSE            0.348599    None    None
# HALLMARK_KRAS_SIGNALING_DN                    0.173279    None    None
# HALLMARK_KRAS_SIGNALING_UP                    0.285714    None    None
# HALLMARK_MITOTIC_SPINDLE                     -0.345106    None    None
# HALLMARK_MTORC1_SIGNALING                     0.284535    None    None
# HALLMARK_MYC_TARGETS_V1                       0.395186    None    None
# HALLMARK_MYC_TARGETS_V2                       0.395186    None    None
# HALLMARK_MYOGENESIS                          -0.348522    None    None
# HALLMARK_NOTCH_SIGNALING                     -0.636273    None    None
# HALLMARK_OXIDATIVE_PHOSPHORYLATION           -0.198767    None    None
# HALLMARK_P53_PATHWAY                          0.270004    None    None
# HALLMARK_PANCREAS_BETA_CELLS                  0.650252    None    None
# HALLMARK_PEROXISOME                          -0.378785    None    None
# HALLMARK_PI3K_AKT_MTOR_SIGNALING             -0.583584    None    None
# HALLMARK_PROTEIN_SECRETION                    0.461937    None    None
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY     -0.393180    None    None
# HALLMARK_SPERMATOGENESIS                     -0.461384    None    None
# HALLMARK_TGF_BETA_SIGNALING                   0.254915    None    None
# HALLMARK_TNFA_SIGNALING_VIA_NFKB              0.379171    None    None
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE            0.240964    None    None
# HALLMARK_UV_RESPONSE_DN                      -0.367140    None    None
# HALLMARK_UV_RESPONSE_UP                      -0.351759    None    None
# HALLMARK_WNT_BETA_CATENIN_SIGNALING          -0.608826    None    None
# HALLMARK_XENOBIOTIC_METABOLISM               -0.435075    None    None

# %% [markdown]
# ## GSEA

# %%
sa_la = pd.Series([0, 0, 0, 1, 1, 1], dtype=float)

sa_la.index = ["Sample {}".format(ie) for ie in sa_la.index]

nu_se_st = gsea.run_gsea(
    sc_ge_sa,  # Gene-by-sample score; DataFrame
    sa_la,  # Sample label; Series
    gm,  # Gene sets; set-to-genes dict or DataFrame
    no="-0-",  # Normalization method; "-0-", "0-1", "1234", "log"
    ra="si",  # Ranking method; "ic", "si", "co", "tt", "di", "ra", "lo"
    mi=5,  # Minimum gene set size; int
    ma=500,  # Maximum gene set size; int
    we=1.0,  # Weight used for "ks" and "auc"; float
    me="ks",  # Enrichment method; "ks", "auc", "js"
    se=1729,  # Random seed; int
    pe="label",  # Permutation type; "gene_set", "label"
    n_pe=1000,  # Number of permutations; int
    n_pl=25,  # Number of extreme gene sets to plot; int
    ad=None,  # Additional gene sets to plot; list of str
    pa="~/Downloads/",  # directory path to write the gene-set-by-statistic and plots; str
)

nu_se_st
# Out:
# Normalized each sample (method -0-).
# Selected 50 gene sets (5 <= size <= 500).
#                                             Enrichment P-Value Q-Value
# HALLMARK_ADIPOGENESIS                        -0.486624    None    None
# HALLMARK_ALLOGRAFT_REJECTION                  0.322709    None    None
# HALLMARK_ANDROGEN_RESPONSE                    0.362303    None    None
# HALLMARK_ANGIOGENESIS                         0.619340    None    None
# HALLMARK_APICAL_JUNCTION                     -0.486973    None    None
# HALLMARK_APICAL_SURFACE                      -0.621092    None    None
# HALLMARK_APOPTOSIS                            0.248485    None    None
# HALLMARK_BILE_ACID_METABOLISM                 0.539790    None    None
# HALLMARK_CHOLESTEROL_HOMEOSTASIS             -0.441392    None    None
# HALLMARK_COAGULATION                         -0.286147    None    None
# HALLMARK_COMPLEMENT                          -0.282607    None    None
# HALLMARK_DNA_REPAIR                          -0.354774    None    None
# HALLMARK_E2F_TARGETS                          0.432297    None    None
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION    0.160420    None    None
# HALLMARK_ESTROGEN_RESPONSE_EARLY             -0.108735    None    None
# HALLMARK_ESTROGEN_RESPONSE_LATE               0.162776    None    None
# HALLMARK_FATTY_ACID_METABOLISM                0.418838    None    None
# HALLMARK_G2M_CHECKPOINT                      -0.309060    None    None
# HALLMARK_GLYCOLYSIS                          -0.285626    None    None
# HALLMARK_HEDGEHOG_SIGNALING                   0.200842    None    None
# HALLMARK_HEME_METABOLISM                     -0.553024    None    None
# HALLMARK_HYPOXIA                              0.248966    None    None
# HALLMARK_IL2_STAT5_SIGNALING                  0.215615    None    None
# HALLMARK_IL6_JAK_STAT3_SIGNALING              0.446339    None    None
# HALLMARK_INFLAMMATORY_RESPONSE               -0.229428    None    None
# HALLMARK_INTERFERON_ALPHA_RESPONSE            0.273313    None    None
# HALLMARK_INTERFERON_GAMMA_RESPONSE            0.336212    None    None
# HALLMARK_KRAS_SIGNALING_DN                   -0.175937    None    None
# HALLMARK_KRAS_SIGNALING_UP                    0.285714    None    None
# HALLMARK_MITOTIC_SPINDLE                     -0.380582    None    None
# HALLMARK_MTORC1_SIGNALING                    -0.389565    None    None
# HALLMARK_MYC_TARGETS_V1                       0.395186    None    None
# HALLMARK_MYC_TARGETS_V2                       0.395186    None    None
# HALLMARK_MYOGENESIS                          -0.256641    None    None
# HALLMARK_NOTCH_SIGNALING                     -0.636273    None    None
# HALLMARK_OXIDATIVE_PHOSPHORYLATION           -0.198959    None    None
# HALLMARK_P53_PATHWAY                          0.258256    None    None
# HALLMARK_PANCREAS_BETA_CELLS                  0.374122    None    None
# HALLMARK_PEROXISOME                          -0.333528    None    None
# HALLMARK_PI3K_AKT_MTOR_SIGNALING             -0.583584    None    None
# HALLMARK_PROTEIN_SECRETION                    0.467062    None    None
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY     -0.393180    None    None
# HALLMARK_SPERMATOGENESIS                     -0.461384    None    None
# HALLMARK_TGF_BETA_SIGNALING                   0.345422    None    None
# HALLMARK_TNFA_SIGNALING_VIA_NFKB              0.409154    None    None
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE            0.240964    None    None
# HALLMARK_UV_RESPONSE_DN                      -0.367140    None    None
# HALLMARK_UV_RESPONSE_UP                      -0.351759    None    None
# HALLMARK_WNT_BETA_CATENIN_SIGNALING          -0.608826    None    None
# HALLMARK_XENOBIOTIC_METABOLISM               -0.444802    None    None
